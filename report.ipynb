# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
books = pd.read_csv('book.csv', engine = 'python')
books
# Out:
#               등록번호             청구기호  \
# 0     BRP000452213        744-코215ㅂ
# 1     BRP000452214        340-콘223ㅈ
# 2     BRP000452215       843.6-스31ㅅ
# 3     BRP000452216         231-정66ㅋ
# 4     BRP000452217      233.24-김79ㄷ
# ...            ...              ...
# 2552  BSD000008097  洋 747-R989g-5-1
# 2553  BSD000008098   洋 747-E13t-2-2
# 2554  BSD000008099  洋 747-S557i-2-1
# 2555  BSD000008100  洋 747-L791i-1-1
# 2556  BSD000008101     洋 377.7-L22g
#
#                                                      서명  \
# 0            (미리엄 웹스터) 보캐뷸러리 빌더 : 읽기만 해도 기억되는 스토리텔링 영단어
# 1                                   정치 이야기, 뭔데 이렇게 재밌어?
# 2                                          손힐=Thornhill
# 3              칼뱅주의 5대 교리 완전정복 : 도르트 신경의 관점에서 이해하고 적용하기
# 4                                        다윗 언약 : 인류의 헌장
# ...                                                 ...
# 2552                            Georgina and the Dragon
# 2553                                 Today and long ago
# ...

# %%
group_names = ['어림','보통','늙음']
books['나이'],mybin = pd.cut(books['발행년'],3,labels=group_names,retbins=True)
books
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-5b0c92abc5a8> in <module>
#       1 group_names = ['어림','보통','늙음']
# ----> 2 books['나이'],mybin = pd.cut(books['발행년'],3,labels=group_names,retbins=True)
#       3 books
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     221
#     222         rng = (nanops.nanmin(x), nanops.nanmax(x))
# --> 223         mn, mx = [mi + 0.0 for mi in rng]
#     224
#     225         if np.isinf(mn) or np.isinf(mx):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in <listcomp>(.0)
#     221
#     222         rng = (nanops.nanmin(x), nanops.nanmax(x))
# --> 223         mn, mx = [mi + 0.0 for mi in rng]
#     224
#     225         if np.isinf(mn) or np.isinf(mx):
#
# ...

# %%
books = pd.concat([books, pd.get_dummies(csv_data['등급'])],axis=1,sort=False)
books
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '등급'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-3d0789ce5ecd> in <module>
# ...
